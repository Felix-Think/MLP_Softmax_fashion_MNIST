# %%
import torch 
import torchvision
from torchvision.datasets import FashionMNIST
from torch.utils.data import DataLoader
from torchvision import transforms
from torch import nn
from torch import optim

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Load data

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0,), (1.0/255.0,))])

train_dataset = FashionMNIST(root ='data',
                             train = True,
                             download = True,
                             transform = transform)
train_loader = DataLoader(dataset = train_dataset, batch_size = 1024, num_workers = 4, shuffle = True)

test_dataset = FashionMNIST(root = 'data',
                            train = False,
                            download= True,
                            transform = transform)
test_loader = DataLoader(dataset = test_dataset, batch_size = 1024, num_workers = 4, shuffle = False)

# %%
#Test
img, _ = train_dataset[0]
#Plot by matplotlib
from matplotlib import pyplot as plt
import numpy as np

img = img.numpy()
img = np.transpose(img, (1, 2, 0))
plt.imshow(img)

# %%
# Define the function show images
def show_images(image):
    fig = plt.figure(figsize = (9, 9))
    img = image.numpy()
    img = np.transpose(img, (1, 2, 0))
    plt.imshow(img)
for i, (images, labels) in enumerate(train_loader, 0):
    plt.axis('off')
    show_images(torchvision.utils.make_grid(images[:10]))
    break

# %% [markdown]
# # DEFINE THE MODEL

# %%
model = nn.Sequential( nn.Flatten(), 
                       nn.Linear(784, 10)) # 28x28 = 784

model = model.to(device)
print(model)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=10, bias=True)
# )

# %%
#Initialize the weights
inputs_tensor = torch.rand(5, 28, 28).to(device)
outputs = model(inputs_tensor)
print(outputs.shape)
# Out:
# torch.Size([5, 10])

# %% [markdown]
# # LOSS, OPTIMIZER, EVALUATIOn FUNCTION

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr = 0.00001)

# %%
# Evaluate the model
def evaluation(model, test_loader, criterion):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)

            # Calculate the loss
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            total  += labels.size(0)

            # Calculate the accuracy
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
    accuracy = 100 * correct / total
    test_loss = test_loss / len(test_loader)
    return test_loss, accuracy

# %%
test_loss, accuracy = evaluation(model, test_loader, criterion)
print(f'Test loss: {test_loss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Test loss: 119.0362
# Test Accuracy: 5.4300

# %%
#Train model
train_accuracies = []
test_accuracies = []
train_losses = []
test_losses = []
max_epochs = 100

for epoch in range(max_epochs):
    running_loss = 0.0
    running_corrects = 0
    total = 0
    for i, (images, labels) in enumerate(train_loader, 0):
        images, labels = images.to(device), labels.to(device)
        
        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        running_loss += loss.item()

        #Determine the predicted classses
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        running_corrects += (predicted == labels).sum().item()
        # Backward pass
        loss.backward()
        optimizer.step()

    epoch_accuracy = 100 * running_corrects / total
    epoch_loss = running_loss / (i + 1)
    test_loss, test_accuracy = evaluation(model, test_loader, criterion)
    print(f'Epoch: {epoch + 1}/{max_epochs}: Train Loss: {epoch_loss:.4f} Train Accuracy: {epoch_accuracy:.4f} Test Loss: {test_loss:.4f} Test Accuracy: {test_accuracy:.4f}')

    #save the plot
    train_accuracies.append(epoch_accuracy)
    test_accuracies.append(test_accuracy)
    train_losses.append(epoch_loss)
    test_losses.append(test_loss)
# Out:
# Epoch: 1/100: Train Loss: 31.0527 Train Accuracy: 29.8950 Test Loss: 17.0783 Test Accuracy: 43.5600
# Epoch: 2/100: Train Loss: 13.7068 Train Accuracy: 50.3450 Test Loss: 12.3868 Test Accuracy: 54.4700
# Epoch: 3/100: Train Loss: 10.8822 Train Accuracy: 58.0600 Test Loss: 10.6847 Test Accuracy: 59.0300
# Epoch: 4/100: Train Loss: 9.6145 Train Accuracy: 61.7083 Test Loss: 9.7109 Test Accuracy: 61.9500
# Epoch: 5/100: Train Loss: 8.8229 Train Accuracy: 63.9717 Test Loss: 9.0399 Test Accuracy: 63.8600
# Epoch: 6/100: Train Loss: 8.2465 Train Accuracy: 65.6217 Test Loss: 8.5461 Test Accuracy: 65.5100
# Epoch: 7/100: Train Loss: 7.8040 Train Accuracy: 66.8033 Test Loss: 8.1672 Test Accuracy: 66.2600
# Epoch: 8/100: Train Loss: 7.4505 Train Accuracy: 67.7700 Test Loss: 7.8017 Test Accuracy: 67.3500
# Epoch: 9/100: Train Loss: 7.1506 Train Accuracy: 68.5933 Test Loss: 7.5223 Test Accuracy: 67.8500
# Epoch: 10/100: Train Loss: 6.8962 Train Accuracy: 69.2400 Test Loss: 7.2793 Test Accuracy: 68.4100
# Epoch: 11/100: Train Loss: 6.6765 Train Accuracy: 69.7783 Test Loss: 7.0623 Test Accuracy: 69.0800
# Epoch: 12/100: Train Loss: 6.4663 Train Accuracy: 70.2667 Test Loss: 6.8678 Test Accuracy: 69.6800
# Epoch: 13/100: Train Loss: 6.2904 Train Accuracy: 70.8583 Test Loss: 6.7048 Test Accuracy: 69.9400
# Epoch: 14/100: Train Loss: 6.1261 Train Accuracy: 71.2667 Test Loss: 6.5558 Test Accuracy: 70.3400
# Epoch: 15/100: Train Loss: 5.9830 Train Accuracy: 71.5950 Test Loss: 6.4257 Test Accuracy: 70.7400
# Epoch: 16/100: Train Loss: 5.8497 Train Accuracy: 71.8983 Test Loss: 6.2778 Test Accuracy: 70.9800
# Epoch: 17/100: Train Loss: 5.7181 Train Accuracy: 72.2000 Test Loss: 6.1358 Test Accuracy: 71.3200
# Epoch: 18/100: Train Loss: 5.6083 Train Accuracy: 72.5117 Test Loss: 6.0202 Test Accuracy: 71.7000
# Epoch: 19/100: Train Loss: 5.4957 Train Accuracy: 72.7883 Test Loss: 5.9233 Test Accuracy: 72.0700
# Epoch: 20/100: Train Loss: 5.3991 Train Accuracy: 72.9950 Test Loss: 5.8484 Test Accuracy: 71.8900
# Epoch: 21/100: Train Loss: 5.3117 Train Accuracy: 73.3500 Test Loss: 5.7556 Test Accuracy: 72.4600
# Epoch: 22/100: Train Loss: 5.2304 Train Accuracy: 73.5567 Test Loss: 5.6557 Test Accuracy: 72.4300
# Epoch: 23/100: Train Loss: 5.1375 Train Accuracy: 73.7283 Test Loss: 5.5827 Test Accuracy: 72.8200
# Epoch: 24/100: Train Loss: 5.0600 Train Accuracy: 73.9200 Test Loss: 5.4781 Test Accuracy: 73.1000
# Epoch: 25/100: Train Loss: 4.9897 Train Accuracy: 74.0700 Test Loss: 5.4223 Test Accuracy: 73.0700
# Epoch: 26/100: Train Loss: 4.9159 Train Accuracy: 74.2950 Test Loss: 5.3244 Test Accuracy: 73.4900
# Epoch: 27/100: Train Loss: 4.8421 Train Accuracy: 74.4383 Test Loss: 5.2575 Test Accuracy: 73.5300
# Epoch: 28/100: Train Loss: 4.7751 Train Accuracy: 74.5433 Test Loss: 5.1993 Test Accuracy: 73.6700
# Epoch: 29/100: Train Loss: 4.7260 Train Accuracy: 74.7367 Test Loss: 5.1476 Test Accuracy: 73.7800
# Epoch: 30/100: Train Loss: 4.6678 Train Accuracy: 74.8567 Test Loss: 5.0919 Test Accuracy: 73.8300
# Epoch: 31/100: Train Loss: 4.6076 Train Accuracy: 74.9967 Test Loss: 5.0220 Test Accuracy: 73.9200
# Epoch: 32/100: Train Loss: 4.5517 Train Accuracy: 75.1467 Test Loss: 4.9761 Test Accuracy: 74.0100
# Epoch: 33/100: Train Loss: 4.5012 Train Accuracy: 75.2317 Test Loss: 4.9171 Test Accuracy: 74.2500
# Epoch: 34/100: Train Loss: 4.4484 Train Accuracy: 75.3217 Test Loss: 4.9016 Test Accuracy: 73.9100
# Epoch: 35/100: Train Loss: 4.4077 Train Accuracy: 75.4583 Test Loss: 4.8298 Test Accuracy: 74.5500
# Epoch: 36/100: Train Loss: 4.3573 Train Accuracy: 75.5817 Test Loss: 4.7716 Test Accuracy: 74.5700
# Epoch: 37/100: Train Loss: 4.3160 Train Accuracy: 75.6983 Test Loss: 4.7271 Test Accuracy: 74.5200
# Epoch: 38/100: Train Loss: 4.2693 Train Accuracy: 75.7983 Test Loss: 4.7428 Test Accuracy: 74.0800
# Epoch: 39/100: Train Loss: 4.2339 Train Accuracy: 75.8433 Test Loss: 4.6418 Test Accuracy: 74.7500
# Epoch: 40/100: Train Loss: 4.1865 Train Accuracy: 76.0050 Test Loss: 4.6059 Test Accuracy: 74.8100
# Epoch: 41/100: Train Loss: 4.1520 Train Accuracy: 76.1433 Test Loss: 4.5959 Test Accuracy: 74.4900
# Epoch: 42/100: Train Loss: 4.1141 Train Accuracy: 76.2017 Test Loss: 4.5195 Test Accuracy: 74.9100
# Epoch: 43/100: Train Loss: 4.0737 Train Accuracy: 76.2333 Test Loss: 4.4912 Test Accuracy: 75.1800
# Epoch: 44/100: Train Loss: 4.0425 Train Accuracy: 76.3750 Test Loss: 4.4583 Test Accuracy: 74.9600
# Epoch: 45/100: Train Loss: 4.0043 Train Accuracy: 76.3933 Test Loss: 4.4267 Test Accuracy: 75.2200
# Epoch: 46/100: Train Loss: 3.9669 Train Accuracy: 76.5317 Test Loss: 4.3839 Test Accuracy: 75.2900
# Epoch: 47/100: Train Loss: 3.9406 Train Accuracy: 76.5950 Test Loss: 4.3601 Test Accuracy: 75.0400
# Epoch: 48/100: Train Loss: 3.9081 Train Accuracy: 76.6683 Test Loss: 4.3160 Test Accuracy: 75.4400
# Epoch: 49/100: Train Loss: 3.8635 Train Accuracy: 76.7600 Test Loss: 4.2807 Test Accuracy: 75.3600
# Epoch: 50/100: Train Loss: 3.8473 Train Accuracy: 76.8000 Test Loss: 4.2797 Test Accuracy: 75.1200
# Epoch: 51/100: Train Loss: 3.8177 Train Accuracy: 76.9100 Test Loss: 4.2462 Test Accuracy: 75.2200
# Epoch: 52/100: Train Loss: 3.7876 Train Accuracy: 76.9083 Test Loss: 4.1987 Test Accuracy: 75.5200
# Epoch: 53/100: Train Loss: 3.7587 Train Accuracy: 77.0617 Test Loss: 4.1701 Test Accuracy: 75.4700
# Epoch: 54/100: Train Loss: 3.7282 Train Accuracy: 77.0767 Test Loss: 4.1401 Test Accuracy: 75.6300
# Epoch: 55/100: Train Loss: 3.7032 Train Accuracy: 77.1317 Test Loss: 4.1100 Test Accuracy: 75.8500
# Epoch: 56/100: Train Loss: 3.6761 Train Accuracy: 77.1633 Test Loss: 4.1072 Test Accuracy: 75.6500
# Epoch: 57/100: Train Loss: 3.6545 Train Accuracy: 77.2050 Test Loss: 4.0686 Test Accuracy: 75.7100
# Epoch: 58/100: Train Loss: 3.6295 Train Accuracy: 77.3333 Test Loss: 4.0332 Test Accuracy: 75.9300
# Epoch: 59/100: Train Loss: 3.6054 Train Accuracy: 77.3567 Test Loss: 4.0060 Test Accuracy: 76.0800
# Epoch: 60/100: Train Loss: 3.5786 Train Accuracy: 77.3767 Test Loss: 3.9879 Test Accuracy: 75.8700
# Epoch: 61/100: Train Loss: 3.5535 Train Accuracy: 77.4150 Test Loss: 3.9523 Test Accuracy: 76.2000
# Epoch: 62/100: Train Loss: 3.5309 Train Accuracy: 77.4533 Test Loss: 3.9456 Test Accuracy: 75.9900
# Epoch: 63/100: Train Loss: 3.5170 Train Accuracy: 77.4883 Test Loss: 3.9222 Test Accuracy: 76.2800
# Epoch: 64/100: Train Loss: 3.4839 Train Accuracy: 77.6000 Test Loss: 3.8999 Test Accuracy: 76.0900
# Epoch: 65/100: Train Loss: 3.4675 Train Accuracy: 77.6467 Test Loss: 3.8627 Test Accuracy: 76.3100
# Epoch: 66/100: Train Loss: 3.4511 Train Accuracy: 77.7283 Test Loss: 3.8496 Test Accuracy: 76.2600
# Epoch: 67/100: Train Loss: 3.4297 Train Accuracy: 77.7233 Test Loss: 3.8612 Test Accuracy: 75.8000
# Epoch: 68/100: Train Loss: 3.4067 Train Accuracy: 77.7683 Test Loss: 3.8065 Test Accuracy: 76.3800
# Epoch: 69/100: Train Loss: 3.3868 Train Accuracy: 77.8167 Test Loss: 3.8258 Test Accuracy: 75.8700
# Epoch: 70/100: Train Loss: 3.3718 Train Accuracy: 77.8917 Test Loss: 3.7697 Test Accuracy: 76.2400
# Epoch: 71/100: Train Loss: 3.3529 Train Accuracy: 77.8283 Test Loss: 3.7688 Test Accuracy: 76.3300
# Epoch: 72/100: Train Loss: 3.3279 Train Accuracy: 77.9700 Test Loss: 3.7491 Test Accuracy: 76.6100
# Epoch: 73/100: Train Loss: 3.3086 Train Accuracy: 77.9217 Test Loss: 3.7202 Test Accuracy: 76.2600
# Epoch: 74/100: Train Loss: 3.2922 Train Accuracy: 77.9900 Test Loss: 3.6816 Test Accuracy: 76.5600
# Epoch: 75/100: Train Loss: 3.2724 Train Accuracy: 78.0433 Test Loss: 3.7070 Test Accuracy: 76.0600
# Epoch: 76/100: Train Loss: 3.2615 Train Accuracy: 78.0733 Test Loss: 3.6921 Test Accuracy: 75.9400
# Epoch: 77/100: Train Loss: 3.2373 Train Accuracy: 78.0533 Test Loss: 3.6564 Test Accuracy: 76.7500
# Epoch: 78/100: Train Loss: 3.2165 Train Accuracy: 78.1183 Test Loss: 3.6187 Test Accuracy: 76.6400
# Epoch: 79/100: Train Loss: 3.2001 Train Accuracy: 78.1917 Test Loss: 3.5959 Test Accuracy: 76.4900
# Epoch: 80/100: Train Loss: 3.1820 Train Accuracy: 78.2850 Test Loss: 3.5768 Test Accuracy: 76.8200
# Epoch: 81/100: Train Loss: 3.1658 Train Accuracy: 78.2350 Test Loss: 3.5815 Test Accuracy: 76.4100
# Epoch: 82/100: Train Loss: 3.1507 Train Accuracy: 78.2583 Test Loss: 3.5561 Test Accuracy: 76.6200
# Epoch: 83/100: Train Loss: 3.1302 Train Accuracy: 78.3817 Test Loss: 3.5310 Test Accuracy: 76.6600
# Epoch: 84/100: Train Loss: 3.1249 Train Accuracy: 78.2950 Test Loss: 3.5249 Test Accuracy: 76.8200
# Epoch: 85/100: Train Loss: 3.1083 Train Accuracy: 78.3833 Test Loss: 3.5150 Test Accuracy: 76.7500
# Epoch: 86/100: Train Loss: 3.0908 Train Accuracy: 78.4200 Test Loss: 3.4977 Test Accuracy: 76.5600
# Epoch: 87/100: Train Loss: 3.0776 Train Accuracy: 78.4283 Test Loss: 3.4942 Test Accuracy: 76.4100
# Epoch: 88/100: Train Loss: 3.0561 Train Accuracy: 78.4567 Test Loss: 3.4625 Test Accuracy: 76.6700
# Epoch: 89/100: Train Loss: 3.0455 Train Accuracy: 78.4783 Test Loss: 3.4417 Test Accuracy: 76.6200
# Epoch: 90/100: Train Loss: 3.0199 Train Accuracy: 78.5917 Test Loss: 3.4339 Test Accuracy: 76.6000
# Epoch: 91/100: Train Loss: 3.0082 Train Accuracy: 78.5967 Test Loss: 3.4826 Test Accuracy: 76.2300
# Epoch: 92/100: Train Loss: 3.0047 Train Accuracy: 78.5633 Test Loss: 3.4295 Test Accuracy: 76.5600
# Epoch: 93/100: Train Loss: 2.9898 Train Accuracy: 78.6817 Test Loss: 3.4218 Test Accuracy: 77.2600
# Epoch: 94/100: Train Loss: 2.9719 Train Accuracy: 78.7000 Test Loss: 3.3894 Test Accuracy: 76.8000
# Epoch: 95/100: Train Loss: 2.9529 Train Accuracy: 78.7283 Test Loss: 3.3624 Test Accuracy: 76.9600
# Epoch: 96/100: Train Loss: 2.9434 Train Accuracy: 78.7567 Test Loss: 3.3575 Test Accuracy: 76.6400
# Epoch: 97/100: Train Loss: 2.9289 Train Accuracy: 78.7950 Test Loss: 3.3265 Test Accuracy: 76.9400
# Epoch: 98/100: Train Loss: 2.9169 Train Accuracy: 78.7733 Test Loss: 3.3086 Test Accuracy: 76.9500
# Epoch: 99/100: Train Loss: 2.9046 Train Accuracy: 78.8133 Test Loss: 3.2985 Test Accuracy: 77.1300
# Epoch: 100/100: Train Loss: 2.8920 Train Accuracy: 78.8400 Test Loss: 3.2866 Test Accuracy: 77.0300

# %%
#Plot train and test losses
plt.plot(train_losses, label = 'Train loss')
plt.plot(test_losses, label = 'Test loss')
plt.legend()
plt.show()

# %%
#Plot train and test accuracies
plt.plot(train_accuracies, label = 'Train accuracy')
plt.plot(test_accuracies, label = 'Test accuracy')
plt.legend()
plt.show()
